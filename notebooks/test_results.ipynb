# %% [markdown]
# # Manual evaluation questions

# %% [markdown]
# ### 1

# %% [markdown]
# Filename:

# %% [markdown]
# **Paragraph**: On 26 March 2010, the European Council agreed to the Commission’s proposal to launch a new strategy ‘Europe 2020’. One of the priorities of the Europe 2020 strategy is sustainable growth to be achieved by promoting a more resource-efficient, more sustainable and more competitive economy. That strategy put energy infrastructures at the forefront as part of the flagship initiative ‘Resource efficient Europe’, by underlining the need to urgently upgrade Europe’s networks, interconnecting them at the continental level, in particular to integrate renewable energy sources.

# %% [markdown]
# **Question**: What is Europe 2020?

# %% [markdown]
# # Evaluation notes
#
# In this notebook we protocoll the results of tests that we perform with different configurations of the langchain chain.

# %% [markdown]
# Chunk sizes:
# - 256/32
#     - higher retriever F1 but lower BERTscore
# - 1024/256
#     - more "context context"
#     - lower retriever F1 but higher BERTscore
#
# Embedding Models:
#
# **`BAAI/bge-large-en-v1.5` with 5 retrieved documents**
# - retriever_recall: 0.69 -> 69% of the relevant documents are retrieved
# - retriever_precision: 0.138 -> 13.8% of the retrieved documents are relevant
#     - this could come from the fact that the oracle only links one GT-document so we are searching for "the needle in the haystack" and the other sources are not considered ground truth
#     - However, there is still the possiblity that more than one chunk from the same Eur-Lex document is retrieved which should increase the precision
# - retriever_f1: 0.23
# - answer_bertscore_f1: 0.85
# -
# **`BAAI/bge-large-en-v1.5` with 20 retrieved documents**
# - retriever_recall: 0.8 -> unsurprisingly, more relevant documents are retrieved
# - retriever_precision: 0.04 -> less documents are relevant
# - retriever_f1: 0.08
# - answer_bertscore_f1: 0.84 -> more documents do not necessarily mean better results
#
# -> @MrWhatsItToYaa and @psaegert found that llama2 can already answer many question without the need for a retriever.
# -> We therefore compare the no-rag-answer with the answer of the full pipeline from now on.
# -> The score difference between the two answers will be the score that the retriever adds to the answer.

# %% [markdown]
# ## Normal / average configurations (if not specified otherwise in Test X chapter)
# Model: llama2 \
# preprocessing_steps: [remove_html_tags_preprocessor] \
# splitter: recursive_character_test_splitter \
# embeddings: GPT4AllEmbeddings \
# retriever: FAISS \
# chat_history_window_size: 2

# %% [markdown]
# ## Test 1
#
# With "normal" settings the retriever recall seems to get better for smaller chunk sizes. We get 0.69 for chunk size 1000(overlap 256), 0.79 for chuck size 256(overlap 32) and 0.86 for chunk size 100(overlap 10).

# %% [markdown]
# Unfortunately the answer_bertscore_f1 drops for smaller chunk sizes: 0.847, 0,841, 0.833 for the mentioned chunk sizes.

# %% [markdown]
# Too counteract this problem we will now try to increase the number of retrieved documents for smaller chunk sizes.

# %% [markdown]
# ## Test 2
#
# For larger numbers of retrived documents the retriever recall rises as expected. For a chunksize of 100 (overlap 10) and 50 retrieved documents we het 99% retreiver recall and 1.98 % retriever percision. The drop in presicion is expected. The answer_bertscore_f1 is 83% for the given settings.

# %% [markdown]
# ## Test 3

# %% [markdown]
# Using a chunk size of 500 (50 overlap) with 50 retreived documents which results in an enormous prompt does not make a real difference. retriever_recall is 95%, retriever_precision is 1.9%,m retriever f1 is 3.73% and answer_bertscore_f1 is 83.46%

# %% [markdown]
# ---

# %% [markdown]
# ## Metrics

# %%
# Silver Data
# Out:
#                                        A_BERT_RAG_F1  A_BERT_RAG_DELTA_F1  \
# 256_10_nlc_bge_fn_mistral.yaml                 0.867                0.026
# 256_10_nlc_bge_fn_mistral_enrich.yaml          0.866                0.023
# sem_40_nlc_bge_fn_mistral.yaml                 0.861                0.021
# 256_10_nlc_bge_fn_mixtral.yaml                 0.861                0.018
# 512_10_nlc_bge.yaml                            0.852                0.024
# 256_10_bge.yaml                                0.851                0.026
# 256_10_nlc_bge_fn_enrich.yaml                  0.849                0.023
# 1024_5_nlc_bge.yaml                            0.849                0.021
# 256_10_g4a.yaml                                0.848                0.023
# 256_10_nlc_bge_fn.yaml                         0.847                0.019
# 256_10_nlc_g4a_fn.yaml                         0.847                0.019
# 256_10_nlc_bge.yaml                            0.846                0.017
# sem_40_nlc_bge_fn.yaml                         0.846                0.019
# 1024_10_nlc_bge.yaml                           0.846                0.018
# 512_5_nlc_bge.yaml                             0.846                0.017
# 256_1_nlc_bge.yaml                             0.844                0.017
# 256_10_nlc_g4a.yaml                            0.844                0.017
# 512_1_nlc_bge.yaml                             0.843                0.016
# 1024_1_nlc_bge.yaml                            0.843                0.016
# 256_5_nlc_bge.yaml                             0.842                0.014
# 256_10_nlc_bge_fn_orca2.yaml                   0.829                0.008
# 256_20_g4a_nomodel.yaml                        0.808                0.808
#
#                                        A_BERT_F1  A_AR_F1  A_BL_BL  A_RGL_SUM  \
# 256_10_nlc_bge_fn_mistral.yaml             0.841    0.909    0.070      0.227
# 256_10_nlc_bge_fn_mistral_enrich.yaml      0.843    0.891    0.063      0.206
# sem_40_nlc_bge_fn_mistral.yaml             0.840    0.839    0.065      0.196
# 256_10_nlc_bge_fn_mixtral.yaml             0.843    0.914    0.060      0.193
# 512_10_nlc_bge.yaml                        0.828    0.915    0.053      0.162
# 256_10_bge.yaml                            0.825    0.912    0.047      0.143
# 256_10_nlc_bge_fn_enrich.yaml              0.826    0.919    0.051      0.144
# 1024_5_nlc_bge.yaml                        0.828    0.920    0.037      0.141
# 256_10_g4a.yaml                            0.825    0.918    0.042      0.129
# 256_10_nlc_bge_fn.yaml                     0.828    0.923    0.046      0.142
# 256_10_nlc_g4a_fn.yaml                     0.828    0.921    0.048      0.145
# 256_10_nlc_bge.yaml                        0.830    0.923    0.042      0.141
# sem_40_nlc_bge_fn.yaml                     0.827    0.915    0.046      0.149
# 1024_10_nlc_bge.yaml                       0.828    0.908    0.037      0.130
# 512_5_nlc_bge.yaml                         0.828    0.920    0.041      0.135
# 256_1_nlc_bge.yaml                         0.826    0.907    0.031      0.128
# 256_10_nlc_g4a.yaml                        0.827    0.919    0.041      0.135
# 512_1_nlc_bge.yaml                         0.827    0.917    0.036      0.127
# 1024_1_nlc_bge.yaml                        0.827    0.916    0.031      0.125
# 256_5_nlc_bge.yaml                         0.828    0.924    0.033      0.124
# 256_10_nlc_bge_fn_orca2.yaml               0.821    0.617    0.024      0.086
# 256_20_g4a_nomodel.yaml                    0.000    0.898    0.009      0.033
#
#                                        RET_AP_1  RET_AP_10  RET_RC_1  \
# 256_10_nlc_bge_fn_mistral.yaml            0.164      0.176     0.164
# 256_10_nlc_bge_fn_mistral_enrich.yaml     0.119      0.146     0.119
# sem_40_nlc_bge_fn_mistral.yaml            0.075      0.089     0.075
# 256_10_nlc_bge_fn_mixtral.yaml            0.164      0.176     0.164
# 512_10_nlc_bge.yaml                       0.075      0.087     0.075
# 256_10_bge.yaml                           0.179      0.216     0.179
# 256_10_nlc_bge_fn_enrich.yaml             0.119      0.146     0.119
# 1024_5_nlc_bge.yaml                       0.045        NaN     0.045
# 256_10_g4a.yaml                           0.090      0.132     0.090
# 256_10_nlc_bge_fn.yaml                    0.164      0.176     0.164
# 256_10_nlc_g4a_fn.yaml                    0.119      0.135     0.119
# 256_10_nlc_bge.yaml                       0.179      0.216     0.179
# sem_40_nlc_bge_fn.yaml                    0.075      0.089     0.075
# 1024_10_nlc_bge.yaml                      0.045      0.062     0.045
# 512_5_nlc_bge.yaml                        0.075        NaN     0.075
# 256_1_nlc_bge.yaml                        0.179        NaN     0.179
# 256_10_nlc_g4a.yaml                       0.090      0.132     0.090
# 512_1_nlc_bge.yaml                        0.075        NaN     0.075
# 1024_1_nlc_bge.yaml                       0.045        NaN     0.045
# 256_5_nlc_bge.yaml                        0.179        NaN     0.179
# 256_10_nlc_bge_fn_orca2.yaml              0.164      0.176     0.164
# 256_20_g4a_nomodel.yaml                   0.119      0.135     0.119
#
#                                        RET_RC_10  RET_RR  RET_NDCG
# 256_10_nlc_bge_fn_mistral.yaml             0.224   0.176     0.164
# 256_10_nlc_bge_fn_mistral_enrich.yaml      0.209   0.146     0.119
# sem_40_nlc_bge_fn_mistral.yaml             0.119   0.089     0.075
# 256_10_nlc_bge_fn_mixtral.yaml             0.224   0.176     0.164
# 512_10_nlc_bge.yaml                        0.134   0.087     0.075
# 256_10_bge.yaml                            0.284   0.216     0.179
# 256_10_nlc_bge_fn_enrich.yaml              0.209   0.146     0.119
# 1024_5_nlc_bge.yaml                          NaN   0.060     0.045
# 256_10_g4a.yaml                            0.254   0.132     0.090
# 256_10_nlc_bge_fn.yaml                     0.224   0.176     0.164
# 256_10_nlc_g4a_fn.yaml                     0.179   0.135     0.119
# 256_10_nlc_bge.yaml                        0.284   0.216     0.179
# sem_40_nlc_bge_fn.yaml                     0.119   0.089     0.075
# 1024_10_nlc_bge.yaml                       0.090   0.062     0.045
# 512_5_nlc_bge.yaml                           NaN   0.085     0.075
# 256_1_nlc_bge.yaml                           NaN   0.179     0.179
# 256_10_nlc_g4a.yaml                        0.254   0.132     0.090
# 512_1_nlc_bge.yaml                           NaN   0.075     0.075
# 1024_1_nlc_bge.yaml                          NaN   0.045     0.045
# 256_5_nlc_bge.yaml                           NaN   0.214     0.179
# 256_10_nlc_bge_fn_orca2.yaml               0.224   0.176     0.164
# 256_20_g4a_nomodel.yaml                    0.179   0.136     0.119

# %%
# Bronze Data
# Out:
#                                        A_BERT_RAG_F1  A_BERT_RAG_DELTA_F1  \
# 256_10_nlc_bge_fn_mistral.yaml                 0.860                0.020
# 256_10_nlc_bge_fn_mistral_enrich.yaml          0.858                0.018
# 256_10_nlc_bge_fn_mixtral.yaml                 0.854                0.014
# 1024_5_nlc_bge.yaml                            0.848                0.019
# sem_40_nlc_bge_fn_mistral.yaml                 0.847                0.009
# 1024_10_nlc_bge.yaml                           0.847                0.019
# 512_10_nlc_bge.yaml                            0.845                0.021
# 1024_1_nlc_bge.yaml                            0.843                0.015
# 512_5_nlc_bge.yaml                             0.843                0.018
# 256_10_nlc_bge_fn.yaml                         0.841                0.016
# 256_10_nlc_bge_fn_enrich.yaml                  0.841                0.014
# 256_10_bge.yaml                                0.840                0.013
# 256_10_nlc_g4a_fn.yaml                         0.840                0.013
# 256_10_g4a.yaml                                0.839                0.015
# 512_1_nlc_bge.yaml                             0.838                0.015
# 256_1_nlc_bge.yaml                             0.838                0.013
# 256_10_nlc_g4a.yaml                            0.837                0.013
# 256_10_nlc_bge.yaml                            0.836                0.011
# 256_5_nlc_bge.yaml                             0.835                0.010
# sem_40_nlc_bge_fn.yaml                         0.833                0.009
# 256_10_nlc_bge_fn_orca2.yaml                   0.825                0.003
# 256_20_g4a_nomodel.yaml                        0.805                0.805
#
#                                        A_BERT_F1  A_AR_F1  A_BL_BL  A_RGL_SUM  \
# 256_10_nlc_bge_fn_mistral.yaml             0.840    0.890    0.052      0.169
# 256_10_nlc_bge_fn_mistral_enrich.yaml      0.840    0.910    0.050      0.172
# 256_10_nlc_bge_fn_mixtral.yaml             0.840    0.906    0.043      0.149
# 1024_5_nlc_bge.yaml                        0.829    0.907    0.038      0.130
# sem_40_nlc_bge_fn_mistral.yaml             0.838    0.868    0.030      0.119
# 1024_10_nlc_bge.yaml                       0.828    0.903    0.048      0.132
# 512_10_nlc_bge.yaml                        0.824    0.912    0.035      0.119
# 1024_1_nlc_bge.yaml                        0.828    0.905    0.032      0.117
# 512_5_nlc_bge.yaml                         0.824    0.915    0.033      0.121
# 256_10_nlc_bge_fn.yaml                     0.825    0.916    0.033      0.107
# 256_10_nlc_bge_fn_enrich.yaml              0.826    0.914    0.033      0.115
# 256_10_bge.yaml                            0.827    0.913    0.023      0.098
# 256_10_nlc_g4a_fn.yaml                     0.826    0.917    0.037      0.112
# 256_10_g4a.yaml                            0.824    0.913    0.026      0.089
# 512_1_nlc_bge.yaml                         0.824    0.913    0.028      0.107
# 256_1_nlc_bge.yaml                         0.825    0.901    0.025      0.094
# 256_10_nlc_g4a.yaml                        0.824    0.912    0.023      0.088
# 256_10_nlc_bge.yaml                        0.825    0.913    0.022      0.093
# 256_5_nlc_bge.yaml                         0.825    0.904    0.024      0.095
# sem_40_nlc_bge_fn.yaml                     0.825    0.907    0.023      0.089
# 256_10_nlc_bge_fn_orca2.yaml               0.822    0.610    0.020      0.068
# 256_20_g4a_nomodel.yaml                    0.000    0.880    0.007      0.027
#
#                                        RET_AP_1  RET_AP_10  RET_RC_1  \
# 256_10_nlc_bge_fn_mistral.yaml            0.568      0.664     0.568
# 256_10_nlc_bge_fn_mistral_enrich.yaml     0.500      0.623     0.500
# 256_10_nlc_bge_fn_mixtral.yaml            0.568      0.664     0.568
# 1024_5_nlc_bge.yaml                       0.250        NaN     0.250
# sem_40_nlc_bge_fn_mistral.yaml            0.359      0.440     0.359
# 1024_10_nlc_bge.yaml                      0.250      0.366     0.250
# 512_10_nlc_bge.yaml                       0.398      0.522     0.398
# 1024_1_nlc_bge.yaml                       0.250        NaN     0.250
# 512_5_nlc_bge.yaml                        0.398        NaN     0.398
# 256_10_nlc_bge_fn.yaml                    0.568      0.664     0.568
# 256_10_nlc_bge_fn_enrich.yaml             0.500      0.623     0.500
# 256_10_bge.yaml                           0.438      0.554     0.438
# 256_10_nlc_g4a_fn.yaml                    0.361      0.454     0.361
# 256_10_g4a.yaml                           0.376      0.477     0.376
# 512_1_nlc_bge.yaml                        0.398        NaN     0.398
# 256_1_nlc_bge.yaml                        0.438        NaN     0.438
# 256_10_nlc_g4a.yaml                       0.376      0.477     0.376
# 256_10_nlc_bge.yaml                       0.438      0.554     0.438
# 256_5_nlc_bge.yaml                        0.438        NaN     0.438
# sem_40_nlc_bge_fn.yaml                    0.359      0.440     0.359
# 256_10_nlc_bge_fn_orca2.yaml              0.568      0.664     0.568
# 256_20_g4a_nomodel.yaml                   0.361      0.454     0.361
#
#                                        RET_RC_10  RET_RR  RET_NDCG
# 256_10_nlc_bge_fn_mistral.yaml             0.852   0.664     0.568
# 256_10_nlc_bge_fn_mistral_enrich.yaml      0.865   0.623     0.500
# 256_10_nlc_bge_fn_mixtral.yaml             0.852   0.664     0.568
# 1024_5_nlc_bge.yaml                          NaN   0.353     0.250
# sem_40_nlc_bge_fn_mistral.yaml             0.621   0.440     0.359
# 1024_10_nlc_bge.yaml                       0.605   0.366     0.250
# 512_10_nlc_bge.yaml                        0.777   0.522     0.398
# 1024_1_nlc_bge.yaml                          NaN   0.250     0.250
# 512_5_nlc_bge.yaml                           NaN   0.511     0.398
# 256_10_nlc_bge_fn.yaml                     0.852   0.664     0.568
# 256_10_nlc_bge_fn_enrich.yaml              0.865   0.623     0.500
# 256_10_bge.yaml                            0.790   0.554     0.438
# 256_10_nlc_g4a_fn.yaml                     0.660   0.454     0.361
# 256_10_g4a.yaml                            0.670   0.477     0.376
# 512_1_nlc_bge.yaml                           NaN   0.398     0.398
# 256_1_nlc_bge.yaml                           NaN   0.438     0.438
# 256_10_nlc_g4a.yaml                        0.670   0.477     0.376
# 256_10_nlc_bge.yaml                        0.790   0.554     0.438
# 256_5_nlc_bge.yaml                           NaN   0.543     0.438
# sem_40_nlc_bge_fn.yaml                     0.621   0.440     0.359
# 256_10_nlc_bge_fn_orca2.yaml               0.852   0.664     0.568
# 256_20_g4a_nomodel.yaml                    0.660   0.456     0.361
